# %% [markdown]
# ## Processing Data

# %%
#------------autoreloader
# %load_ext autoreload
# %autoreload 2

# %%
#------------setting up the path
import sys
sys.path.append('../')

# %%
#------------importing the src functions
from src.process_data.data import load_data, get_info, get_nan, drop_col, save_data

# %% [markdown]
# ### ------------- Scaled Data -------------

# %%
#-------------Train data
df_train_scaled_path = '../data/intermidiate/scaled/train.csv'
df_train_scaled = load_data(df_train_scaled_path)
df_train_scaled.head()
# Out:
#    Source  Destination  Total_Stops     Price  Airline_IndiGo  \
# 0       2            2            0  0.027497               1
# 1       1            1            2  0.075920               0
# 2       0            0            2  0.155917               0
# 3       1            1            1  0.057348               1
# 4       2            2            1  0.148457               1
#
#    Airline_Jet Airways  Airline_other  Additional_Info_Some info  \
# 0                    0              0                          0
# 1                    0              0                          0
# 2                    1              0                          0
# 3                    0              0                          0
# 4                    0              0                          0
#
#    Date_of_Journey_day  Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  \
# 0             0.884615               0.000000       0.956522         0.363636
# ...

# %%
#---------first check, veryfying the null values
get_nan(df_train_scaled)
# Out:
# Source                       0
# Destination                  0
# Total_Stops                  0
# Price                        0
# Airline_IndiGo               0
# Airline_Jet Airways          0
# Airline_other                0
# Additional_Info_Some info    0
# Date_of_Journey_day          0
# Date_of_Journey_month        0
# Dep_Time_hour                0
# Dep_Time_minute              0
# Arrival_Time_hour            0
# Arrival_Time_minute          0
# Duration_in_hours            0
# dtype: int64

# %%
#-------------veryfying with df_info
get_info(df_train_scaled)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Source                     10683 non-null  int64
#  1   Destination                10683 non-null  int64
#  2   Total_Stops                10683 non-null  int64
#  3   Price                      10683 non-null  float64
#  4   Airline_IndiGo             10683 non-null  int64
#  5   Airline_Jet Airways        10683 non-null  int64
#  6   Airline_other              10683 non-null  int64
#  7   Additional_Info_Some info  10683 non-null  int64
#  8   Date_of_Journey_day        10683 non-null  float64
#  9   Date_of_Journey_month      10683 non-null  float64
#  10  Dep_Time_hour              10683 non-null  float64
#  11  Dep_Time_minute            10683 non-null  float64
#  12  Arrival_Time_hour          10683 non-null  float64
# ...

# %%
#-----------separating the price column and saving them differently
price_scaled = df_train_scaled['Price']
price_scaled
# Out:
# 0        0.027497
# 1        0.075920
# 2        0.155917
# 3        0.057348
# 4        0.148457
#            ...
# 10678    0.030198
# 10679    0.030687
# 10680    0.070351
# 10681    0.140046
# 10682    0.128535
# Name: Price, Length: 10683, dtype: float64

# %%
#-------------dropping the price column from the main data,
drop_col(df_train_scaled, 'Price')
df_train_scaled.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       2            2            0               1                    0
# 1       1            1            2               0                    0
# 2       0            0            2               0                    1
# 3       1            1            1               1                    0
# 4       2            2            1               1                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0             0.884615
# 1              0                          0             0.000000
# 2              0                          0             0.307692
# 3              0                          0             0.423077
# 4              0                          0             0.000000
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
#--------------loading the test scaled data
df_test_scaled_path = '../data/intermidiate/scaled/test.csv'
df_test_scaled = load_data(df_test_scaled_path)
df_test_scaled.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       0            0            1               0                    1
# 1       1            1            1               1                    0
# 2       0            0            1               0                    1
# 3       0            0            1               0                    0
# 4       2            2            0               0                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0             0.192308
# 1              0                          0             0.423077
# 2              0                          1             0.769231
# 3              1                          0             0.769231
# 4              1                          0             0.884615
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
#------------performing the initial checks
get_nan(df_test_scaled)
# Out:
# Source                       0
# Destination                  0
# Total_Stops                  0
# Airline_IndiGo               0
# Airline_Jet Airways          0
# Airline_other                0
# Additional_Info_Some info    0
# Date_of_Journey_day          0
# Date_of_Journey_month        0
# Dep_Time_hour                0
# Dep_Time_minute              0
# Arrival_Time_hour            0
# Arrival_Time_minute          0
# Duration_in_hours            0
# dtype: int64

# %%
#-----------------now we have all three data, we'll steup the paths and save them
model_ready_scaled_price_path = '../data/model_ready/scaled/price_scaled.csv'
model_ready_scaled_train_path = '../data/model_ready/scaled/train_scaled.csv'
model_ready_scaled_test_path = '../data/model_ready/scaled/test_scaled.csv'

# %%
#--------------saving the data
save_data(df_train_scaled, model_ready_scaled_train_path)
save_data(df_test_scaled, model_ready_scaled_test_path)
save_data(price_scaled, model_ready_scaled_price_path)

# %%
#---------------veryfying if, it went well
df_train_scaled = load_data(model_ready_scaled_train_path)
df_train_scaled.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       2            2            0               1                    0
# 1       1            1            2               0                    0
# 2       0            0            2               0                    1
# 3       1            1            1               1                    0
# 4       2            2            1               1                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0             0.884615
# 1              0                          0             0.000000
# 2              0                          0             0.307692
# 3              0                          0             0.423077
# 4              0                          0             0.000000
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
price_scaled = load_data(model_ready_scaled_price_path)
price_scaled.head()
# Out:
#       Price
# 0  0.027497
# 1  0.075920
# 2  0.155917
# 3  0.057348
# 4  0.148457

# %% [markdown]
# ### ----------------- Non Scaled data -----------------

# %%
#-------------Train data
df_train_non_scaled_path = '../data/intermidiate/non-scaled/train.csv'
df_train_non_scaled = load_data(df_train_non_scaled_path)
df_train_non_scaled.head()
# Out:
#    Source  Destination  Total_Stops  Price  Airline_IndiGo  \
# 0       2            2            0   3897               1
# 1       1            1            2   7662               0
# 2       0            0            2  13882               0
# 3       1            1            1   6218               1
# 4       2            2            1  13302               1
#
#    Airline_Jet Airways  Airline_other  Additional_Info_Some info  \
# 0                    0              0                          0
# 1                    0              0                          0
# 2                    1              0                          0
# 3                    0              0                          0
# 4                    0              0                          0
#
#    Date_of_Journey_day  Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  \
# 0                   24                      3             22               20
# ...

# %%
#---------first check, veryfying the null values
get_nan(df_train_non_scaled)
# Out:
# Source                       0
# Destination                  0
# Total_Stops                  0
# Price                        0
# Airline_IndiGo               0
# Airline_Jet Airways          0
# Airline_other                0
# Additional_Info_Some info    0
# Date_of_Journey_day          0
# Date_of_Journey_month        0
# Dep_Time_hour                0
# Dep_Time_minute              0
# Arrival_Time_hour            0
# Arrival_Time_minute          0
# Duration_in_hours            0
# dtype: int64

# %%
#-------------veryfying with df_info
get_info(df_train_non_scaled)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Source                     10683 non-null  int64
#  1   Destination                10683 non-null  int64
#  2   Total_Stops                10683 non-null  int64
#  3   Price                      10683 non-null  int64
#  4   Airline_IndiGo             10683 non-null  int64
#  5   Airline_Jet Airways        10683 non-null  int64
#  6   Airline_other              10683 non-null  int64
#  7   Additional_Info_Some info  10683 non-null  int64
#  8   Date_of_Journey_day        10683 non-null  int64
#  9   Date_of_Journey_month      10683 non-null  int64
#  10  Dep_Time_hour              10683 non-null  int64
#  11  Dep_Time_minute            10683 non-null  int64
#  12  Arrival_Time_hour          10683 non-null  int64
# ...

# %%
#-----------separating the price column and saving them differently
price_non_scaled = df_train_non_scaled['Price']
price_non_scaled
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10683, dtype: int64

# %%
#-------------dropping the price column from the main data,
drop_col(df_train_non_scaled, 'Price')
df_train_non_scaled.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       2            2            0               1                    0
# 1       1            1            2               0                    0
# 2       0            0            2               0                    1
# 3       1            1            1               1                    0
# 4       2            2            1               1                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0                   24
# 1              0                          0                    1
# 2              0                          0                    9
# 3              0                          0                   12
# 4              0                          0                    1
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
#--------------loading the test scaled data
df_test_non_scaled_path = '../data/intermidiate/non-scaled/test.csv'
df_test_non_scaled = load_data(df_test_non_scaled_path)
df_test_non_scaled.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       0            0            1               0                    1
# 1       1            1            1               1                    0
# 2       0            0            1               0                    1
# 3       0            0            1               0                    0
# 4       2            2            0               0                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0                    6
# 1              0                          0                   12
# 2              0                          1                   21
# 3              1                          0                   21
# 4              1                          0                   24
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
#------------performing the initial checks
get_nan(df_test_scaled)
# Out:
# Source                       0
# Destination                  0
# Total_Stops                  0
# Airline_IndiGo               0
# Airline_Jet Airways          0
# Airline_other                0
# Additional_Info_Some info    0
# Date_of_Journey_day          0
# Date_of_Journey_month        0
# Dep_Time_hour                0
# Dep_Time_minute              0
# Arrival_Time_hour            0
# Arrival_Time_minute          0
# Duration_in_hours            0
# dtype: int64

# %%
#-----------------now we have all three data, we'll steup the paths and save them
model_ready_non_scaled_price_path = '../data/model_ready/non-scaled/price_non_scaled.csv'
model_ready_non_scaled_train_path = '../data/model_ready/non-scaled/train_non_scaled.csv'
model_ready_non_scaled_test_path = '../data/model_ready/non-scaled/test_non_scaled.csv'

# %%
#--------------saving the data
save_data(df_train_non_scaled, model_ready_non_scaled_train_path)
save_data(df_test_non_scaled, model_ready_non_scaled_test_path)
save_data(price_non_scaled, model_ready_non_scaled_price_path)

# %%
#---------------veryfying if, it went well
df_train_non_scaled = load_data(model_ready_non_scaled_train_path)
df_train_non_scaled.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       2            2            0               1                    0
# 1       1            1            2               0                    0
# 2       0            0            2               0                    1
# 3       1            1            1               1                    0
# 4       2            2            1               1                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0                   24
# 1              0                          0                    1
# 2              0                          0                    9
# 3              0                          0                   12
# 4              0                          0                    1
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
price_non_scaled = load_data(model_ready_non_scaled_price_path)
price_non_scaled.head()
# Out:
#    Price
# 0   3897
# 1   7662
# 2  13882
# 3   6218
# 4  13302
