# %% [markdown]
# ## Plot graphs : df_test

# %% [markdown]
# ### checking the graphs and then making it good for the trees

# %%
#------------autoreloader
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../../..')

# %%
from src.data.load_data import load_data, get_info, get_nan, get_shape, save_data
from src.featured_engineering.processing_cols import unique_values, value_counts, one_hot, label_encoding, split_numerical, split_numerical_further, columns_to_drop
from src.featured_engineering.plot_features import plot_graphs

# %%
#----------------data path
df_path = '../../../data/intermidiate/test.csv'

# %%
#-------------loading the data and df.head
df = load_data(df_path)
df.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       0            0            1               0                    1
# 1       1            1            1               1                    0
# 2       0            0            1               0                    1
# 3       0            0            1               0                    0
# 4       2            2            0               0                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0                    6
# 1              0                          0                   12
# 2              0                          1                   21
# 3              1                          0                   21
# 4              1                          0                   24
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...

# %%
#--------------features to plot in df_train
features_to_plot = [
    'Date_of_Journey_day', 'Date_of_Journey_month', 'Dep_Time_hour', 'Dep_Time_minute', 'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_in_hours', 
    ]
features_to_plot
# Out:
# ['Date_of_Journey_day',
#  'Date_of_Journey_month',
#  'Dep_Time_hour',
#  'Dep_Time_minute',
#  'Arrival_Time_hour',
#  'Arrival_Time_minute',
#  'Duration_in_hours']

# %%
for feature in features_to_plot : 
    print(f"feature  : {feature}")
    plot_graphs(df, feature)
# Out:
# feature  : Date_of_Journey_day
# feature  : Date_of_Journey_month
# feature  : Dep_Time_hour
# feature  : Dep_Time_minute
# feature  : Arrival_Time_hour
# feature  : Arrival_Time_minute
# feature  : Duration_in_hours

# %% [markdown]
# ##### ------------completetion---------------

# %%
### Since it's for the tree based models, that's why I just plotted them all at once and didn't went for the preprocessing
### the dataset is completed and good to train for the tree based models like : Decision Tree, Random forest etc.

# %%
#------------------final checks
#------------------df.info()
df_info = get_info(df)
df_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Source                     2671 non-null   int64
#  1   Destination                2671 non-null   int64
#  2   Total_Stops                2671 non-null   int64
#  3   Airline_IndiGo             2671 non-null   int64
#  4   Airline_Jet Airways        2671 non-null   int64
#  5   Airline_other              2671 non-null   int64
#  6   Additional_Info_Some info  2671 non-null   int64
#  7   Date_of_Journey_day        2671 non-null   int64
#  8   Date_of_Journey_month      2671 non-null   int64
#  9   Dep_Time_hour              2671 non-null   int64
#  10  Dep_Time_minute            2671 non-null   int64
#  11  Arrival_Time_hour          2671 non-null   int64
#  12  Arrival_Time_minute        2671 non-null   int64
# ...

# %%
#-------------check for the nan values
nan_values = get_nan(df)
nan_values
# Out:
# Source                       0
# Destination                  0
# Total_Stops                  0
# Airline_IndiGo               0
# Airline_Jet Airways          0
# Airline_other                0
# Additional_Info_Some info    0
# Date_of_Journey_day          0
# Date_of_Journey_month        0
# Dep_Time_hour                0
# Dep_Time_minute              0
# Arrival_Time_hour            0
# Arrival_Time_minute          0
# Duration_in_hours            0
# dtype: int64

# %%
#-----------------setting up the path to save it
df_test_tree_path = '../../../data/preprocessed/trees/test.csv'
df_test_tree_path
# Out:
# '../../../data/preprocessed/trees/test.csv'

# %%
#---------------saving the data
df = save_data(df, df_test_tree_path)

# %%
#-----------------checking if everything went good
df = load_data(df_test_tree_path)
df.head()
# Out:
#    Source  Destination  Total_Stops  Airline_IndiGo  Airline_Jet Airways  \
# 0       0            0            1               0                    1
# 1       1            1            1               1                    0
# 2       0            0            1               0                    1
# 3       0            0            1               0                    0
# 4       2            2            0               0                    0
#
#    Airline_other  Additional_Info_Some info  Date_of_Journey_day  \
# 0              0                          0                    6
# 1              0                          0                   12
# 2              0                          1                   21
# 3              1                          0                   21
# 4              1                          0                   24
#
#    Date_of_Journey_month  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# ...
