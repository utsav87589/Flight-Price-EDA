# %% [markdown]
# ## Predictions : Valid data

# %%
#------------autoreloader
# %load_ext autoreload
# %autoreload 2

# %%
### importing the system path
import sys
sys.path.append('../')

# %%
from src.basic.load_check_data import load_data, get_nan_duplicates_shape, get_info
from src.predictions.pred_and_plot import best_model_predict, other_model_predict

# %%
### best model from trees : Random forest regressor
### best model from distance based models : KNN

# %% [markdown]
# ### ============= Tree based models ==================

# %%
### setting up the data path
valid_tree_path = '../data/model_ready/valid_tree.csv'

# %%
### loading the data
valid_tree = load_data(valid_tree_path)
valid_tree.head()
# Out:
#    Source  Destination  Total_Stops  Airline_Jet Airways  Airline_other  \
# 0       4            4            1                    1              0
# 1       3            3            1                    0              0
# 2       4            4            1                    1              0
# 3       4            4            1                    0              1
# 4       2            2            2                    0              1
#
#    Additional_Info_some info  Date_of_Journey_day  Date_of_Journey_month  \
# 0                          0                    6                      6
# 1                          0                   12                      5
# 2                          1                   21                      5
# 3                          0                   21                      5
# 4                          0                   24                      6
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute  \
# ...

# %%
### some inital checks on the data
get_nan_duplicates_shape(valid_tree)
# Out:
# shape : (2670, 13)
# duplicate values : 30
# Source                       0
# Destination                  0
# Total_Stops                  0
# Airline_Jet Airways          0
# Airline_other                0
# Additional_Info_some info    0
# Date_of_Journey_day          0
# Date_of_Journey_month        0
# Dep_Time_hour                0
# Dep_Time_minute              0
# Arrival_Time_hour            0
# Arrival_Time_minute          0
# Duration_hour                0
# dtype: int64

# %%
### get_info
get_info(valid_tree)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2670 entries, 0 to 2669
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Source                     2670 non-null   int64
#  1   Destination                2670 non-null   int64
#  2   Total_Stops                2670 non-null   int64
#  3   Airline_Jet Airways        2670 non-null   int64
#  4   Airline_other              2670 non-null   int64
#  5   Additional_Info_some info  2670 non-null   int64
#  6   Date_of_Journey_day        2670 non-null   int64
#  7   Date_of_Journey_month      2670 non-null   int64
#  8   Dep_Time_hour              2670 non-null   int64
#  9   Dep_Time_minute            2670 non-null   int64
#  10  Arrival_Time_hour          2670 non-null   int64
#  11  Arrival_Time_minute        2670 non-null   int64
#  12  Duration_hour              2670 non-null   int64
# dtypes: int64(13)
# memory usage: 271.3 KB

# %% [markdown]
# ##### Random forst on valid data

# %%
model_path_rfr = '../models/trees/rfr.pkl'
y_pred_best_trees = best_model_predict(valid_tree, best_model_path = model_path_rfr)
y_pred_best_trees
# Out:
# array([14714.   ,  4226.   , 12898.   , ..., 15650.6  , 13653.695,
#         7508.99 ])

# %% [markdown]
# ##### Random forest vs Decision tree

# %%
model_path_dtr = '../models/trees/dtr.pkl'
other_model_predict(valid_tree, y_pred_best_trees, other_model_path = model_path_dtr)
# Out:
# r2 score : 0.8983499435445764
# MAE : 608.4712194002627
# RMSE : 1388.280774498084
# MSE : 1927323.5088409998

# %% [markdown]
# ##### Random forest vs Adaboost regressor

# %%
model_path_abr = '../models/trees/abr.pkl'
other_model_predict(valid_tree, y_pred_best_trees, other_model_path = model_path_abr)
# Out:
# r2 score : 0.3066205371264583
# MAE : 2932.9723128874202
# RMSE : 3625.8429108223795
# MSE : 13146736.813960906

# %% [markdown]
# ##### Random forest vs Gradient boost

# %%
model_path_gbr = '../models/trees/gbr.pkl'
other_model_predict(valid_tree, y_pred_best_trees, other_model_path = model_path_gbr)
# Out:
# r2 score : 0.876611045886886
# MAE : 1014.6028328539776
# RMSE : 1529.542816949947
# MSE : 2339501.2288831794

# %% [markdown]
# ### ============= Distance based models ==================

# %%
### setting up the data path
valid_distance_path = '../data/model_ready/valid_distance.csv'

# %%
### loading up the data
valid_distance = load_data(valid_distance_path)
valid_distance.head()
# Out:
#    Source  Destination  Total_Stops  Airline_Jet Airways  Airline_other  \
# 0       4            4            1                    1              0
# 1       3            3            1                    0              0
# 2       4            4            1                    1              0
# 3       4            4            1                    0              1
# 4       2            2            2                    0              1
#
#    Additional_Info_some info  Date_of_Journey_day  Date_of_Journey_month  \
# 0                          0             0.192308               1.000000
# 1                          0             0.423077               0.666667
# 2                          1             0.769231               0.666667
# 3                          0             0.769231               0.666667
# 4                          0             0.884615               1.000000
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute  \
# ...

# %%
### verification #1
get_nan_duplicates_shape(valid_distance)
# Out:
# shape : (2670, 13)
# duplicate values : 30
# Source                       0
# Destination                  0
# Total_Stops                  0
# Airline_Jet Airways          0
# Airline_other                0
# Additional_Info_some info    0
# Date_of_Journey_day          0
# Date_of_Journey_month        0
# Dep_Time_hour                0
# Dep_Time_minute              0
# Arrival_Time_hour            0
# Arrival_Time_minute          0
# Duration_hour                0
# dtype: int64

# %%
### verification #2
get_info(valid_distance)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2670 entries, 0 to 2669
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Source                     2670 non-null   int64
#  1   Destination                2670 non-null   int64
#  2   Total_Stops                2670 non-null   int64
#  3   Airline_Jet Airways        2670 non-null   int64
#  4   Airline_other              2670 non-null   int64
#  5   Additional_Info_some info  2670 non-null   int64
#  6   Date_of_Journey_day        2670 non-null   float64
#  7   Date_of_Journey_month      2670 non-null   float64
#  8   Dep_Time_hour              2670 non-null   float64
#  9   Dep_Time_minute            2670 non-null   float64
#  10  Arrival_Time_hour          2670 non-null   float64
#  11  Arrival_Time_minute        2670 non-null   float64
#  12  Duration_hour              2670 non-null   float64
# dtypes: float64(7), int64(6)
# ...

# %%
### setting up the scaler_for_price path
scaler_for_price = '../scalers/scaler_for_price.pkl'

# %% [markdown]
# ##### KNN predictions on the valid data

# %%
model_path_knn = '../models/distance/knn.pkl'
y_pred_best_distance = best_model_predict(valid_distance, best_model_path = model_path_knn, scaler_price_path = scaler_for_price)
y_pred_best_distance
# Out:
# array([[14714. ],
#        [ 5644.6],
#        [12793. ],
#        ...,
#        [15827. ],
#        [14780.6],
#        [ 8225.8]])

# %% [markdown]
# ##### KNN vs SVR

# %%
model_path_svr = '../models/distance/svr.pkl'
other_model_predict(valid_distance, y_pred_best_distance, other_model_path = model_path_svr, scaler_price_path = scaler_for_price)
# Out:
# r2 score : 0.5222275696407943
# MAE : 2292.8960220451618
# RMSE : 2868.4762373267117
# MSE : 8228155.92410801

# %% [markdown]
# ##### KNN vs LR

# %%
model_path_lr = '../models/distance/lr.pkl'
other_model_predict(valid_distance, y_pred_best_distance, other_model_path = model_path_lr, scaler_price_path = scaler_for_price)
# Out:
# r2 score : 0.6836460025764234
# MAE : 1659.4465248250538
# RMSE : 2334.1425579424063
# MSE : 5448221.4807979185

# %% [markdown]
# ##### best model of the trees vs best model of the distance

# %%
### making new preds (best distance vs tree)
other_model_predict(valid_distance, y_pred_best_distance, other_model_path = model_path_rfr)
# Out:
# r2 score : -2.014949547094132
# MAE : 5792.662273408239
# RMSE : 7205.775682261294
# MSE : 51923203.18306821

# %%
### making new preds (best tree vs distance)
other_model_predict(valid_distance, y_pred_best_trees, other_model_path = model_path_knn, scaler_price_path = scaler_for_price)
# Out:
# r2 score : 0.8547619731405793
# MAE : 845.3006352992203
# RMSE : 1659.4480739895612
# MSE : 2753767.910267664
